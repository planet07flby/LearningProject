# %% [markdown]
# ## 见于3.Lasso.ipynb

# %%
# 参数： alpha l1_ratio 后者越大L1正则化越强,L2正则化越弱 前者越大二者都越大
# ElasticNetCV

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score
from time import time

t0 = time()
enet = ElasticNet(alpha=0.01, l1_ratio=0.5).fit(X_train, y_train)

y_pred_enet = enet.predict(X_test)
r2_score_enet = r2_score(y_test, y_pred_enet)

# %%
from sklearn.linear_model import ElasticNet

t0 = time()
enet = ElasticNet(alpha=0.02, l1_ratio=0.5).fit(X_train, y_train)

y_pred_enet = enet.predict(X_test)
r2_score_enet = r2_score(y_test, y_pred_enet)

# %%
from sklearn.linear_model import ElasticNetCV
reg = ElasticNetCV(cv=5).fit(X_train, y_train)
reg.alpha_, reg.l1_ratio_

# %% [markdown]
#  $$L(w, b) = \frac{1}{2n} \sum_{i=1}^n (y_i - X_i w - b)^2 + \alpha \cdot \left( \rho \|w\|_1 + \frac{1 - \rho}{2} \|w\|_2^2 \right)$$
