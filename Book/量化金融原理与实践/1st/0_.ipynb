# %% [markdown]
# ## 镜像下载

# %% [markdown]
# ### 在终端输入并运行
# #### pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 聚类
# #### 1. K-means
# #### 2. 层次聚类

# %% [markdown]
# ## 主成分分析

# %% [markdown]
# ## 线性分析
# #### 1.多元回归
# #### 2.逻辑回归
# #### 3.岭回归

# %% [markdown]
# ## 支持向量机

# %% [markdown]
# ## 决策树和随机森林

# %% [markdown]
# ## 神经网络
# #### 1.多层感知机
# #### 2.卷积神经网络
# #### 3.长短期神经网络
