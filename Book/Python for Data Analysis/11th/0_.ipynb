# %% [markdown]
# ## pd.date_range常用freq参数
# ### 日期
#
# #### 每天	'D'
# #### 工作日 'B'
# #### 每周	'W'
# #### 月末	'ME'
# #### 月初	'MS'
# #### 季末 'QE'
# #### 季初	'QS'
# #### 年末	'YE'
# #### 年初	'YS'
#
# ### 时间
#
# #### 小时 'h'
# #### 分钟 'min'
# #### 秒 's'
# #### 毫秒 'ms'
# #### 微秒 'us'
