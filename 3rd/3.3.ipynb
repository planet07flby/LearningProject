# %% [markdown]
# # 3.3 文件和操作系统

# %%
# path = ''
# f = open(path, encoding='utf-8')
# lines = [x.rstrip() for x in f]  # 去掉行终止符
# f.close()

# %%
# with语句可以自动关闭文件f
# with open(path, encoding="utf-8") as f:
#     lines = [x.rstrip() for x in f]

# %%
# r只读 w只写创建新文件并覆盖原来文件 x只写创建新文件不可同名 a追加到现有文件 r+读写
# open(path, mode='r', encoding='utf-8')

# %%
# f.read(10)  # 读取10个字符
# f.tell()  # 返回当前位置(11)
# read方法通过读取字符推进文件对象的位置,tell可以给出当前的位置
# f.seek(0)  # 将位置移动到文件开头
# f.seek(3)  # 将位置移动到第4个字符
# f.readline()  # 读取一行
# f.readlines()  # 读取所有行并返回列表
# f.write('hello\n')  # 写入字符串
# f.writelines(['hello\n', 'world\n'])  # 写入字符串列表
# f.flush()  # 将缓冲区内容写入磁盘

# %% [markdown]
# # End
