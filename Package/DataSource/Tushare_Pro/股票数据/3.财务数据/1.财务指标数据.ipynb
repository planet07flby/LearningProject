# %% [markdown]
# # fina_indicator

# %%
# 描述:获取上市公司财务指标数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.fina_indicator(ts_code='601899.SH',fields='ts_code,end_date,roe,roa,gross_margin,debt_to_assets')
df
# Out:
#       ts_code  end_date      roe      roa  gross_margin  debt_to_assets
# 0   601899.SH  20250930  24.4994  12.9091  6.338309e+10         53.0096
# 1   601899.SH  20250930  24.4994  12.9091  6.338309e+10         53.0096
# 2   601899.SH  20250630  16.5272   8.4364  3.983288e+10         56.3649
# 3   601899.SH  20250331   7.1167   3.7374  1.806350e+10         54.8896
# 4   601899.SH  20241231  25.9213  13.5342  6.186379e+10         55.1876
# ..        ...       ...      ...      ...           ...             ...
# 95  601899.SH  20120930  13.9764  10.8717  8.468535e+09         50.2719
# 96  601899.SH  20120930  13.9764  10.8717  8.468535e+09         50.2719
# 97  601899.SH  20120630   9.4936   7.3198  5.462138e+09         49.9306
# 98  601899.SH  20120630   9.4936   7.3198  5.462138e+09         49.9306
# 99  601899.SH  20120331   4.1832   3.4136  2.470096e+09         44.9211
#
# [100 rows x 6 columns]

# %% [markdown]
# ### 输入输出

# %%
# https://tushare.pro/document/2?doc_id=79

# %% [markdown]
# # End
