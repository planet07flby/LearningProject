# %% [markdown]
# # forecast

# %%
# 描述:获取业绩预告数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.forecast(ts_code='601388.SH',fields='ts_code,ann_date,end_date,type,p_change_min,p_change_max,net_profit_min')
df
# Out:
#       ts_code  ann_date  end_date type  p_change_min  p_change_max  \
# 0   601388.SH  20260128  20251231   预增      620.0000      970.0000
# 1   601388.SH  20250716  20250630   预减      -67.0000      -53.0000
# 2   601388.SH  20250716  20250630   预减      -67.0000      -53.0000
# 3   601388.SH  20250418  20241231   预减      -89.0100      -83.5200
# 4   601388.SH  20250115  20241231   预减      -74.0000      -61.0000
# 5   601388.SH  20250115  20241231   预减      -74.0000      -61.0000
# 6   601388.SH  20240131  20231231   预减      -69.0000      -48.0000
# 7   601388.SH  20240131  20231231   预减      -69.0000      -48.0000
# 8   601388.SH  20230715  20230630   预减      -72.0000      -52.0000
# 9   601388.SH  20230715  20230630   预减      -72.0000      -52.0000
# 10  601388.SH  20230131  20221231   预减      -67.0000      -47.0000
# 11  601388.SH  20230131  20221231   预减      -67.0000      -47.0000
# 12  601388.SH  20220118  20211231   预增       71.0000       97.0000
# ...

# %% [markdown]
# ### 输入输出

# %%
# https://tushare.pro/document/2?doc_id=45

# %% [markdown]
# # End
