# %% [markdown]
# # cashflow

# %%
# 描述:获取上市公司现金流量表

# %%
import tushare as  ts
pro = ts.pro_api()
df = pro.cashflow(ts_code='601388.SH')
df
# Out:
#       ts_code  ann_date f_ann_date  end_date comp_type report_type end_type  \
# 0   601388.SH  20251028   20251028  20250930         1           1        3
# 1   601388.SH  20251028   20251028  20250930         1           1        3
# 2   601388.SH  20250827   20250827  20250630         1           1        2
# 3   601388.SH  20250827   20250827  20250630         1           1        2
# 4   601388.SH  20250429   20250429  20250331         1           1        1
# ..        ...       ...        ...       ...       ...         ...      ...
# 69  601388.SH  20121030   20121030  20110930         1           1        3
# 70  601388.SH  20111216   20111216  20110630         1           1        2
# 71  601388.SH  20120323   20120323  20101231         1           1        4
# 72  601388.SH  20120323   20120323  20091231         1           1        4
# 73  601388.SH  20111216   20111216  20081231         1           1        4
#
# ...

# %% [markdown]
# ### 输入输出

# %%
# https://tushare.pro/document/2?doc_id=44

# %% [markdown]
# # End
