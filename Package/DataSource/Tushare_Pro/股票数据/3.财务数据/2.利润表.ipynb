# %% [markdown]
# # income

# %%
# 描述:获取上市公司财务利润表数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.income(ts_code='601899.SH',start_date='20250101',end_date='20251231',fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,basic_eps,diluted_eps')
df.head()
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps  \
# 0  601899.SH  20251018   20251018  20250930           1         1      1.425
# 1  601899.SH  20250827   20250827  20250630           1         1      0.877
# 2  601899.SH  20250412   20250412  20250331           1         1      0.383
# 3  601899.SH  20250322   20250322  20241231           1         1      1.210
#
#    diluted_eps
# 0        1.396
# 1        0.860
# 2        0.376
# 3        1.200

# %% [markdown]
# ### 输入输出

# %%
# https://tushare.pro/document/2?doc_id=33

# %% [markdown]
# # End
