# %% [markdown]
# # balancesheet

# %%
# 描述:获取上市公司资产负债表

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.balancesheet(ts_code='601899.SH',fields='ts_code,ann_date,f_ann_date,end_date,report_type,comp_type,cap_rese')
df.head()
# Out:
#      ts_code  ann_date f_ann_date  end_date report_type comp_type  \
# 0  601899.SH  20251018   20251018  20250930           1         1
# 1  601899.SH  20251018   20251018  20250930           1         1
# 2  601899.SH  20250827   20250827  20250630           1         1
# 3  601899.SH  20250412   20250412  20250331           1         1
# 4  601899.SH  20250412   20250412  20250331           1         1
#
#        cap_rese
# 0  3.666047e+10
# 1  3.666047e+10
# 2  2.111422e+10
# 3  2.873982e+10
# 4  2.873982e+10

# %% [markdown]
# ### 输入输出

# %%
# https://tushare.pro/document/2?doc_id=36

# %% [markdown]
# # End
