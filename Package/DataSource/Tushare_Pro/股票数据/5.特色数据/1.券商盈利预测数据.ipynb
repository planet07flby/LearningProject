# %% [markdown]
# # report_rc

# %%
# 描述：获取券商(卖方)每天研报的盈利预测数据 daily<=10次 8000

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.report_rc(ts_code='',report_date='20220429')
df.head(10)
# Out:
#      ts_code  name report_date                           report_title  \
# 0  000733.SZ  振华科技    20220429  振华科技：2022Q1归母净利润同比增长146％，结构优化持续增强盈利能力
# 1  000858.SZ   五粮液    20220429                      五粮液：业绩稳健增长，龙头风采依旧
# 2  000858.SZ   五粮液    20220429                      五粮液：业绩稳健增长，龙头风采依旧
# 3  000858.SZ   五粮液    20220429                      五粮液：业绩稳健增长，龙头风采依旧
# 4  000858.SZ   五粮液    20220429                          五粮液：稳中求进，回归价值
# 5  000858.SZ   五粮液    20220429                          五粮液：稳中求进，回归价值
# 6  000858.SZ   五粮液    20220429                          五粮液：稳中求进，回归价值
# 7  000983.SZ  山西焦煤    20220429  山西焦煤2021年报及2022一季报点评：资产注入助力扩张，高分红彰显价值
# 8  000983.SZ  山西焦煤    20220429  山西焦煤2021年报及2022一季报点评：资产注入助力扩张，高分红彰显价值
# 9  000983.SZ  山西焦煤    20220429  山西焦煤2021年报及2022一季报点评：资产注入助力扩张，高分红彰显价值
#
#   report_type classify org_name  author_name quarter       op_rt  ...  \
# 0          点评     一般报告     安信证券  张宝涵,温肇东,马卓群  2024Q4   1273000.0  ...
# ...

# %% [markdown]
# ### 输入输出

# %%
# https://tushare.pro/document/2?doc_id=292

# %% [markdown]
# # End
