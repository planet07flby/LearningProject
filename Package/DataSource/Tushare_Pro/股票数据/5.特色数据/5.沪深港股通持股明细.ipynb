# %% [markdown]
# # hk_hold

# %%
# 描述:获取沪深港股通持股明细 日度南向资金 季度北向资金

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.hk_hold(trade_date='20260226',exchange='HK')
df
# Out:
#      code trade_date   ts_code    name         vol  ratio exchange
# 0       1   20260226  00001.HK      長和    98042755   2.55       HK
# 1       2   20260226  00002.HK    中電控股    49528178   1.95       HK
# 2       3   20260226  00003.HK  香港中華煤氣   589318650   3.15       HK
# 3       4   20260226  00004.HK   九龍倉集團     4880950   0.15       HK
# 4       5   20260226  00005.HK    匯豐控股  1572740577   9.14       HK
# ..    ...        ...       ...     ...         ...    ...      ...
# 873  9990   20260226  09990.HK    祖龍娛樂    48383000   6.03       HK
# 874  9992   20260226  09992.HK    泡泡瑪特   272209417  20.28       HK
# 875  9993   20260226  09993.HK    金輝控股   266575000   6.58       HK
# 876  9995   20260226  09995.HK    榮昌生物   107631249  51.59       HK
# 877  9996   20260226  09996.HK  沛嘉醫療-B    79268100  11.78       HK
#
# [878 rows x 7 columns]

# %% [markdown]
# ### 输入

# %%
# code ts_code trade_date start_date end_date exchange SH沪SZ深HK港

# %% [markdown]
# ### 输出

# %%
# code trade_date ts_code name vol(股) ratio(%) exchange

# %% [markdown]
# # End
