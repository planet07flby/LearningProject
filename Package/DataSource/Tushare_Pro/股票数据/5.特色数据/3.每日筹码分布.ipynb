# %% [markdown]
# # cyq_chips

# %%
# 描述:获取A股每日的筹码分布情况,提供各价位占比

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.cyq_chips(ts_code='600000.SH', trade_date='20220104')
df
# Out:
#       ts_code trade_date  price  percent
# 0   600000.SH   20220104    0.6     0.02
# 1   600000.SH   20220104    0.7     0.02
# 2   600000.SH   20220104    0.8     0.02
# 3   600000.SH   20220104    0.9     0.02
# 4   600000.SH   20220104    1.0     0.02
# ..        ...        ...    ...      ...
# 94  600000.SH   20220104   10.0     0.91
# 95  600000.SH   20220104   10.1     0.90
# 96  600000.SH   20220104   10.2     0.62
# 97  600000.SH   20220104   10.3     0.75
# 98  600000.SH   20220104   10.4     0.42
#
# [99 rows x 4 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date price percent 分位数

# %% [markdown]
# # End
