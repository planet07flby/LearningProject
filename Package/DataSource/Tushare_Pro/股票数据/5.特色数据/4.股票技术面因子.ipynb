# %% [markdown]
# # stk_factor_pro

# %%
# 描述:获取股票每日技术面因子数据,用于跟踪股票当前走势情况 输出参数_bfq表示不复权,_qfq表示前复权,_hfq表示后复权

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stk_factor_pro(ts_code='601899.SH')
df
# Out:
#         ts_code trade_date   open  open_hfq  open_qfq   high  high_hfq  \
# 0     601899.SH   20260226  39.89  86.82856  39.89000  39.96  86.98093
# 1     601899.SH   20260225  39.40  85.76198  39.40000  40.26  87.63394
# 2     601899.SH   20260224  39.49  85.95788  39.49000  39.65  86.30616
# 3     601899.SH   20260213  38.26  83.28054  38.26000  39.04  84.97837
# 4     601899.SH   20260212  39.57  86.13202  39.57000  40.43  88.00398
# ...         ...        ...    ...       ...       ...    ...       ...
# 4284  601899.SH   20080505  10.80  10.80000   4.96164  11.56  11.56000
# 4285  601899.SH   20080430  10.31  10.31000   4.73653  11.20  11.20000
# 4286  601899.SH   20080429  11.28  11.28000   5.18216  11.28  11.28000
# 4287  601899.SH   20080428  12.53  12.53000   5.75642  12.53  12.53000
# 4288  601899.SH   20080425   9.98   9.98000   4.58492  22.00  22.00000
#
#       high_qfq    low   low_hfq  ...  xsii_td1_qfq  xsii_td2_bfq  \
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# https://tushare.pro/document/2?doc_id=328

# %% [markdown]
# # End
