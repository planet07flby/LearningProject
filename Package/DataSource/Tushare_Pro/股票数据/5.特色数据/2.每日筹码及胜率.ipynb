# %% [markdown]
# # cyq_perf

# %%
# 描述:获取A股每日筹码平均成本和胜率情况

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.cyq_perf(ts_code='600000.SH', start_date='20220101', end_date='20220429')
df
# Out:
#       ts_code trade_date  his_low  his_high  cost_5pct  cost_15pct  \
# 0   600000.SH   20220429      0.6      10.4        6.6         7.1
# 1   600000.SH   20220428      0.6      10.4        6.6         7.1
# 2   600000.SH   20220427      0.6      10.4        6.6         7.2
# 3   600000.SH   20220426      0.6      10.4        6.6         7.2
# 4   600000.SH   20220425      0.6      10.4        6.6         7.2
# ..        ...        ...      ...       ...        ...         ...
# 72  600000.SH   20220110      0.6      10.4        6.9         7.3
# 73  600000.SH   20220107      0.6      10.4        6.9         7.3
# 74  600000.SH   20220106      0.6      10.4        6.9         7.3
# 75  600000.SH   20220105      0.6      10.4        6.9         7.3
# 76  600000.SH   20220104      0.6      10.4        6.9         7.4
#
#     cost_50pct  cost_85pct  cost_95pct  weight_avg  winner_rate
# 0          7.9         9.0         9.8        7.98        11.03
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date
# his_low his_high 历史最高/低价
# cost_5pct cost_15pct cost_50pct cost_85pct cost_95pct ...分位成本
# weight_avg 加权平均成本 winner_rate 胜率

# %% [markdown]
# # End
