# %% [markdown]
# # realtime_quote

# %%
# 描述:本接口是tushare org版实时接口的顺延,数据来自网络,且不进入tushare服务器,属于爬虫接口.

# %%
import tushare as ts
pro = ts.pro_api()
df = ts.realtime_quote(ts_code='601899.SH,601388.SH')
df
# Out:
#    NAME    TS_CODE      DATE      TIME   OPEN  PRE_CLOSE  PRICE   HIGH    LOW  \
# 0  紫金矿业  601899.SH  20260226  13:37:19  39.89      39.63  39.19  39.96  38.94
# 1  怡球资源  601388.SH  20260226  13:37:19   4.21       4.20   4.18   4.24   4.14
#
#      BID  ...  A1_V   A1_P  A2_V  A2_P  A3_V   A3_P   A4_V   A4_P   A5_V  \
# 0  39.18  ...    96  39.19   205  39.2   291  39.21    328  39.22    200
# 1   4.18  ...  5896   4.19  6220   4.2  7819   4.21  10057   4.22  10738
#
#     A5_P
# 0  39.23
# 1   4.23
#
# [2 rows x 33 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code
# src 默认:sina新浪(支持多个股票输入,不超过50个) dc东财(只支持单个股票)

# %% [markdown]
# ### 输出

# %%
# name ts_code date time open pre_close price high low
# bid 买一 ask 卖一 volume(sina股,dc手) amount成交金额(元)
# b1_v 委买一(手,下同) b1_p(元,下同) b2_v b2_p ...a1_v 委卖一 a1_p ...

# %% [markdown]
# # End
