# %% [markdown]
# # suspend_d

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.suspend_d(suspend_type='S',trade_date='20200312')
df
# Out:
#       ts_code trade_date suspend_timing suspend_type
# 0   000029.SZ   20200312            NaN            S
# 1   000502.SZ   20200312            NaN            S
# 2   000977.SZ   20200312            NaN            S
# 3   002450.SZ   20200312            NaN            S
# 4   300592.SZ   20200312            NaN            S
# 5   300819.SZ   20200312    09:30-10:00            S
# 6   300821.SZ   20200312    09:30-10:00            S
# 7   600145.SH   20200312            NaN            S
# 8   600228.SH   20200312            NaN            S
# 9   600310.SH   20200312            NaN            S
# 10  600745.SH   20200312            NaN            S
# 11  600766.SH   20200312            NaN            S
# 12  600891.SH   20200312            NaN            S
# 13  601127.SH   20200312            NaN            S
# 14  601162.SH   20200312            NaN            S
# 15  603002.SH   20200312            NaN            S
# 16  603399.SH   20200312            NaN            S
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date
# suspend_type 停复牌类型:S-停牌,R-复牌

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date suspend_type
# suspend_type 日内停牌时间段

# %% [markdown]
# # End
