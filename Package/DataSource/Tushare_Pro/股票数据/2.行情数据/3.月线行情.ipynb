# %% [markdown]
# # monthly

# %% [markdown]
# ## 未复权

# %%
# 描述：获取A股月线数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.monthly(ts_code='000001.SZ', start_date='20180101', end_date='20181101', fields='ts_code,trade_date,open,high,low,close,vol,amount')
df.head()
# Out:
#      ts_code trade_date   open   high   low  close           vol        amount
# 0  000001.SZ   20181031  10.70  11.46  9.70  10.91  2.780156e+09  2.960878e+10
# 1  000001.SZ   20180928  10.09  11.27  9.68  11.05  1.882100e+09  1.942842e+10
# 2  000001.SZ   20180831   9.42  10.43  8.64  10.13  2.189687e+09  2.088672e+10
# 3  000001.SZ   20180731   9.05   9.59  8.45   9.42  2.043028e+09  1.832737e+10
# 4  000001.SZ   20180629  10.15  10.46  8.87   9.09  1.817989e+09  1.791251e+10

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# 同周线
# ts_code trade_date close open high low pre_close change pct_chg vol amount

# %% [markdown]
# # End
