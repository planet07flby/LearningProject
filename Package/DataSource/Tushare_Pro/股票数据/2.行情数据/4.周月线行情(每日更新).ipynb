# %% [markdown]
# # stk_weekly_monthly

# %%
## 未复权

# %%
# 描述：股票周/月线行情(每日更新)

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stk_weekly_monthly(trade_date='20251024',freq='week')
df.head()
# Out:
#      ts_code trade_date  end_date  freq   open   high    low  close  \
# 0  600137.SH   20251024  20251121  week  18.55  21.99  18.31  19.87
# 1  301479.SZ   20251024  20251121  week  87.90  94.99  87.30  92.95
# 2  301273.SZ   20251024  20251121  week  26.29  28.07  26.18  28.00
# 3  600132.SH   20251024  20251121  week  53.44  53.90  53.22  53.28
# 4  301396.SZ   20251024  20251121  week  68.49  69.25  65.59  69.05
#
#    pre_close        vol      amount  change  pct_chg
# 0      18.28  265865.13   531762.20    1.59     8.70
# 1      86.98   48335.68   445965.56    5.97     6.86
# 2      26.09   47219.44   129002.23    1.91     7.32
# 3      53.38   80967.53   433166.79   -0.10    -0.19
# 4      67.37  191565.46  1300468.86    1.68     2.49

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date freq(week或month)

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date end_date freq open high low close pre_close vol amount change pct_chg(未复权)

# %% [markdown]
# # End
