# %% [markdown]
# # adj_factor

# %%
# 描述:本接口由Tushare自行生产,获取股票复权因子,可提取单只股票全部历史复权因子,也可以提取单日全部股票的复权因子.

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.adj_factor(ts_code='600848.SH', start_date='20180101', end_date='20181231')
df.head(20)
# Out:
#       ts_code trade_date  adj_factor
# 0   600848.SH   20181228       2.253
# 1   600848.SH   20181227       2.253
# 2   600848.SH   20181226       2.253
# 3   600848.SH   20181225       2.253
# 4   600848.SH   20181224       2.253
# 5   600848.SH   20181221       2.253
# 6   600848.SH   20181220       2.253
# 7   600848.SH   20181219       2.253
# 8   600848.SH   20181218       2.253
# 9   600848.SH   20181217       2.253
# 10  600848.SH   20181214       2.253
# 11  600848.SH   20181213       2.253
# 12  600848.SH   20181212       2.253
# 13  600848.SH   20181211       2.253
# 14  600848.SH   20181210       2.253
# 15  600848.SH   20181207       2.253
# 16  600848.SH   20181206       2.253
# 17  600848.SH   20181205       2.253
# 18  600848.SH   20181204       2.253
# 19  600848.SH   20181203       2.253

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date adj_factor

# %% [markdown]
# # End
