# %% [markdown]
# # realtime_tick

# %%
# 描述: 由于采集和拼接当日以来的成交全历史,因此接口提取数据时需要一定时间

# %%
import tushare as ts
pro = ts.pro_api()
df = ts.realtime_tick(ts_code='600973.SH')
df
# Out:
# D:\code\LocalTradingSystem\.venv\Lib\site-packages\tushare\stock\histroy_divide.py:75: UserWarning: 正在下载数据，请稍等
#   warnings.warn("正在下载数据，请稍等")
#           TIME  PRICE  CHANGE  VOLUME  AMOUNT TYPE
# 0     09:25:04   7.36    0.00     899  661664   卖盘
# 1     09:30:01   7.36    0.00      46   33856   买盘
# 2     09:30:04   7.36    0.00      10    7359   买盘
# 3     09:30:07   7.35   -0.01      65   47835   卖盘
# 4     09:30:10   7.36    0.01     227  166866   买盘
# ...        ...    ...     ...     ...     ...  ...
# 2363  13:19:43   7.53    0.00      78   58732   买盘
# 2364  13:19:46   7.52   -0.01      18   13549   卖盘
# 2365  13:19:49   7.53    0.01      17   12789   买盘
# 2366  13:19:52   7.52   -0.01     106   79813   卖盘
# 2367  13:19:55   7.53    0.01     253  190509   买盘
#
# [2368 rows x 6 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code
# src sina-默认-新浪  dc-东财

# %% [markdown]
# ### 输出

# %%
# time price change volume(手) amount(元) type(买,卖,中)

# %% [markdown]
# # End
