# %% [markdown]
# # bak_daily

# %%
# 描述:获取备用行情,包括特定的行情指标 5000

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.bak_daily(ts_code='601899.SH',trade_date='20260226')
df
# Out:
#      ts_code trade_date  name  pct_change  close  change   open   high    low  \
# 0  601899.SH   20260226  紫金矿业       -0.66  39.37   -0.26  39.89  39.96  38.94
#
#    pre_close  ...  area  float_mv  total_mv  avg_price  strength  activity  \
# 0      39.63  ...    福建   8110.57  10468.38       39.3     -0.64    5001.0
#
#    avg_turnover  attack  interval_3  interval_6
# 0           0.0     1.1        None        None
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date
# offset 开始行数 limit 最大行数

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date name pct_change close change open high low pre_close
# vol_ratio 量比
# turn_over 换手率
# swing 振幅
# vol 成交量
# amount 成交额
# selling 内盘(主动卖，手)
# buying 外盘(主动买， 手)
# total_share 总股本(亿)
# float_share 流通股本(亿)
# pe 市盈(动)
# industry 所属行业
# area 所属地域
# float_mv 流通市值
# total_mv 总市值
# avg_price 平均价
# strength 强弱度(%)
# activity 活跃度(%)
# avg_turnover 笔换手
# attack 攻击波(%)
# interval_3 近3月涨幅
# interval_6 近6月涨幅

# %% [markdown]
# # End
