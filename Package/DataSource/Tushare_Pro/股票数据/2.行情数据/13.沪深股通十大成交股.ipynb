# %% [markdown]
# # hsgt_top10

# %%
# 描述:获取沪股通、深股通每日前十大成交详细数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.hsgt_top10(trade_date='20260105',market_type='1',fields='trade_date,ts_code,name,close,amount,net_amount,buy,sell')
df['amount'] = df['amount'].astype(int)
df
# Out:
#   trade_date    ts_code  name    close      amount net_amount   buy  sell
# 0   20260105  600118.SH  中国卫星    99.45  1264538849       None  None  None
# 1   20260105  600276.SH  恒瑞医药    63.08  1614110231       None  None  None
# 2   20260105  600519.SH  贵州茅台  1426.00  3239240691       None  None  None
# 3   20260105  601138.SH  工业富联    63.67  1868191856       None  None  None
# 4   20260105  601318.SH  中国平安    72.36  1596544763       None  None  None
# 5   20260105  601899.SH  紫金矿业    35.40  2494187110       None  None  None
# 6   20260105  603259.SH  药明康德    94.57  1576922816       None  None  None
# 7   20260105  603986.SH  兆易创新   235.68  1645510286       None  None  None
# 8   20260105  688012.SH  中微公司   311.33  1421516817       None  None  None
# 9   20260105  688256.SH   寒武纪  1390.00  1642342190       None  None  None

# %% [markdown]
# ### 输入

# %%
# trade_date market_type(1沪3深)

# %% [markdown]
# ### 输出

# %%
# trade_date ts_code name close change rank market_type amount(元) net_amount 净成交金额(元) buy(元) sell(元)

# %% [markdown]
# # End
