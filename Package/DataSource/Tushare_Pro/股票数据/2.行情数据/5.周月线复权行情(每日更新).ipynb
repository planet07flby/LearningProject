# %% [markdown]
# # stk_week_month_adj

# %%
# 描述：股票周/月线行情(复权--每日更新)

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stk_week_month_adj(ts_code='000001.SZ',freq='week')
df.head()
# Out:
#      ts_code trade_date  end_date  freq   open   high    low  close  \
# 0  000001.SZ   20260227  20260224  week  10.93  10.95  10.88  10.91
# 1  000001.SZ   20260213  20260224  week  11.05  11.11  10.90  10.91
# 2  000001.SZ   20260206  20260224  week  10.82  11.14  10.77  11.05
# 3  000001.SZ   20260130  20260224  week  10.98  11.06  10.66  10.83
# 4  000001.SZ   20260123  20260224  week  11.15  11.21  10.98  10.99
#
#    pre_close  open_qfq  ...  low_qfq  close_qfq  open_hfq  high_hfq  low_hfq  \
# 0      10.91     10.93  ...    10.88      10.91   1470.95   1473.64  1464.22
# 1      11.05     11.05  ...    10.90      10.91   1487.10   1495.18  1466.92
# 2      10.83     10.82  ...    10.77      11.05   1456.15   1499.21  1449.42
# 3      10.99     10.98  ...    10.66      10.83   1477.68   1488.45  1434.62
# 4      11.19     11.15  ...    10.98      10.99   1500.56   1508.64  1477.68
#
#    close_hfq         vol      amount  change  pct_chg
# 0    1468.26   602512.40   657487.70    0.00     0.00
# 1    1468.26  2887575.27  3182000.16   -0.14    -1.27
# 2    1487.10  4630517.33  5075309.67    0.22     2.03
# 3    1457.49  6383852.69  6958962.53   -0.16    -1.46
# 4    1479.03  4375771.22  4858324.13   -0.20    -1.79
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date freq

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date end_date freq open high low close pre_close(除权)
# open_qfq high_qfq low_qfq close_qfq ..._hfq
# vol amount change pct_chg(除权)

# %% [markdown]
# # End
