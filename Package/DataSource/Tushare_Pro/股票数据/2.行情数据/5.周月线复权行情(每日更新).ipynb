# %% [markdown]
# # stk_week_month_adj

# %%
# 描述：股票周/月线行情(复权--每日更新)

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stk_week_month_adj(ts_code='000001.SZ',freq='week',adj='qfq')
df.head()
# Out:
#      ts_code trade_date  end_date  freq   open   high    low  close  \
# 0  000001.SZ   20260410  20260408  week  11.12  11.22  10.97  11.22
# 1  000001.SZ   20260403  20260408  week  10.98  11.32  10.94  11.12
# 2  000001.SZ   20260327  20260408  week  10.68  11.05  10.43  11.02
# 3  000001.SZ   20260320  20260408  week  10.93  11.07  10.76  10.77
# 4  000001.SZ   20260313  20260408  week  10.79  11.00  10.73  10.93
#
#    pre_close  open_qfq  ...  low_qfq  close_qfq  open_hfq  high_hfq  low_hfq  \
# 0      11.12     11.12  ...    10.97      11.22   1496.52   1509.98  1476.34
# 1      11.02     10.98  ...    10.94      11.12   1477.68   1523.44  1472.30
# 2      10.77     10.68  ...    10.43      11.02   1437.31   1487.10  1403.66
# 3      10.93     10.93  ...    10.76      10.77   1470.95   1489.79  1448.07
# 4      10.82     10.79  ...    10.73      10.93   1452.11   1480.37  1444.04
#
#    close_hfq         vol      amount  change  pct_chg
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date freq adj

# %% [markdown]
# ### 输出

# %%
# ts_code trade_date end_date freq open high low close pre_close(除权)
# open_qfq high_qfq low_qfq close_qfq ..._hfq
# vol amount change pct_chg(除权)

# %% [markdown]
# # End
