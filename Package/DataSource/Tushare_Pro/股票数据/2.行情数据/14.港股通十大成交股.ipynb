# %% [markdown]
# # ggt_top10

# %%
# 描述:获取港股通每日成交数据,其中包括沪市、深市详细数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.ggt_top10(trade_date='20180727')
df
# Out:
#    trade_date   ts_code    name   close  p_change  rank  market_type  \
# 0    20180727  00175.HK    吉利汽车   18.42   -3.2563   4.0            2
# 1    20180727  00175.HK    吉利汽车   18.42   -3.2563   4.0            4
# 2    20180727  00581.HK  中国东方集团    6.60    5.9390   NaN            4
# 3    20180727  00607.HK    丰盛控股    3.48   -2.5210   NaN            4
# 4    20180727  00700.HK    腾讯控股  373.00   -0.4803   1.0            2
# 5    20180727  00700.HK    腾讯控股  373.00   -0.4803   1.0            4
# 6    20180727  00763.HK    中兴通讯   13.74    0.8811   NaN            4
# 7    20180727  00914.HK    海螺水泥   49.10    2.1852   NaN            4
# 8    20180727  00939.HK    建设银行    7.11   -0.5594   2.0            2
# 9    20180727  01088.HK    中国神华   18.24    3.2843   9.0            2
# 10   20180727  01288.HK    农业银行    3.81    0.0000   5.0            2
# 11   20180727  01299.HK    友邦保险   68.65    0.5124   6.0            2
# 12   20180727  01317.HK    枫叶教育    7.07    1.1445   NaN            4
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date market_type(2沪4深,下同)

# %% [markdown]
# ### 输出

# %%
# trade_date ts_code name close p_change 涨跌幅 rank market_type amount(元,下同) net_amount sh_amount sh_net_amount sh_buy sh_sell sz_amount sz_amount sz_net_amount sz_buy sz_sell

# %% [markdown]
# # End
