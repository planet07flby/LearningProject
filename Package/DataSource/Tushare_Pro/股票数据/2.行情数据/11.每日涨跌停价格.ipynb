# %% [markdown]
# # stk_limit

# %%
# 描述:获取单日全部股票数据涨跌停价格或获取单个股票数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stk_limit(ts_code='002149.SZ', start_date='20190115', end_date='20190615', fields='ts_code,pre_close,up_limit,down_limit')
df.head()
# Out:
#      ts_code  pre_close  up_limit  down_limit
# 0  002149.SZ       9.55     10.51        8.60
# 1  002149.SZ       9.11     10.02        8.20
# 2  002149.SZ       9.08      9.99        8.17
# 3  002149.SZ       8.59      9.45        7.73
# 4  002149.SZ       8.32      9.15        7.49

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# trade_date ts_code pre_close up_limit down_limit

# %% [markdown]
# # End
