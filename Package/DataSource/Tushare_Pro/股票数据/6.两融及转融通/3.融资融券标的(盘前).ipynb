# %% [markdown]
# # margin_secs

# %%
# 描述:获取沪深京三大交易所融资融券标的(包括ETF) 每天盘前更新

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.margin_secs(trade_date='20260226',exchange='SSE')
df
# Out:
#      trade_date    ts_code      name exchange
# 0      20260226  510050.SH    50ETF       SSE
# 1      20260226  510100.SH  SZ50ETF       SSE
# 2      20260226  510150.SH    消费ETF       SSE
# 3      20260226  510180.SH   180ETF       SSE
# 4      20260226  510210.SH    综指ETF       SSE
# ...         ...        ...       ...      ...
# 1965   20260226  688816.SH      C易思       SSE
# 1966   20260226  688818.SH     电科蓝天       SSE
# 1967   20260226  688819.SH     天能股份       SSE
# 1968   20260226  688981.SH     中芯国际       SSE
# 1969   20260226  689009.SH     九号公司       SSE
#
# [1970 rows x 4 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date exchange start_date end_date

# %% [markdown]
# ### 输出

# %%
# trade_date ts_code name exchange

# %% [markdown]
# # End
