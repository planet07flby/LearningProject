# %% [markdown]
# # margin

# %%
# 描述:获取融资融券每日交易汇总数据

# %%
import tushare as ts
import pandas as pd
pro = ts.pro_api()
df = pro.margin(trade_date='20260226',exchange_id='SSE')
# 显示两位小数，不用科学计数法
pd.set_option('display.float_format', '{:.2f}'.format)
df
# Out:
#   trade_date exchange_id             rzye           rzmre           rzche  \
# 0   20260226         SSE 1339956696186.00 118417406073.00 109019990812.00
#
#             rqye        rqmcl           rzrqye          rqyl
# 0 11463801463.00 104426687.00 1351420497649.00 2183697747.00

# %% [markdown]
# ### 输入

# %%
# trade_date start_date end_date exchange_id

# %% [markdown]
# ### 输出

# %%
# trade_date exchange_id
# rzye 融资余额(元)
# rzmre 融资买入额(元)
# rzche 融资偿还额(元)
# rqye 融券余额(元)
# rqmcl 股(标的证券为股票) 份(标的证券为基金或存托凭证) 手(标的证券为债券)
# rzrqye 融资融券余额(元)
# rqyl 融券余量(股,份,手)

# %% [markdown]
# # End
