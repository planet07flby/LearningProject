# %% [markdown]
# # margin_datail

# %%
# 描述:获取沪深两市每日融资融券明细

# %%
import tushare as ts
import pandas as pd
pro = ts.pro_api()
df = pro.margin_detail(ts_code='601899.SH',trade_date='20260226')
# 显示两位小数，不用科学计数法
pd.set_option('display.float_format', '{:.2f}'.format)
df
# Out:
#   trade_date    ts_code           rzye        rqye        rzmre       rqyl  \
# 0   20260226  601899.SH 12795759993.00 75128117.46 927084079.00 1908258.00
#
#          rzche     rqchl    rqmcl         rzrqye
# 0 770629653.00 163200.00 31000.00 12870888110.46

# %% [markdown]
# ### 输入输出

# %%
# 同margin

# %% [markdown]
# # End
