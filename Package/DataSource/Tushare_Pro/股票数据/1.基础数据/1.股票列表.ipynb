# %% [markdown]
# # stock_basic

# %%
import tushare as ts
pro = ts.pro_api()
# 查询当前所有正常上市交易的股票列表
data = pro.stock_basic(exchange='', list_status='L',fields='ts_code,symbol,name,area,industry,list_date')
data.head(20)
# Out:
#       ts_code  symbol   name area industry list_date
# 0   000001.SZ  000001   平安银行   深圳       银行  19910403
# 1   000002.SZ  000002    万科Ａ   深圳     全国地产  19910129
# 2   000004.SZ  000004  *ST国华   深圳     软件服务  19901201
# 3   000006.SZ  000006   深振业Ａ   深圳     区域地产  19920427
# 4   000007.SZ  000007    全新好   深圳     其他商业  19920413
# 5   000008.SZ  000008   神州高铁   北京     运输设备  19920507
# 6   000009.SZ  000009   中国宝安   深圳     电气设备  19910625
# 7   000010.SZ  000010   美丽生态   深圳     建筑工程  19951027
# 8   000011.SZ  000011   深物业A   深圳     房产服务  19920330
# 9   000012.SZ  000012    南玻Ａ   深圳       玻璃  19920228
# 10  000014.SZ  000014   沙河股份   深圳     全国地产  19920602
# 11  000016.SZ  000016   深康佳Ａ   深圳     家用电器  19920327
# 12  000017.SZ  000017   深中华A   深圳       服饰  19920331
# 13  000019.SZ  000019   深粮控股   深圳     农业综合  19921012
# 14  000020.SZ  000020   深华发Ａ   深圳      元器件  19920428
# 15  000021.SZ  000021    深科技   深圳      元器件  19940202
# 16  001872.SZ  001872   招商港口   深圳       港口  19930505
# 17  000025.SZ  000025    特力Ａ   深圳      综合类  19930621
# 18  000026.SZ  000026    飞亚达   深圳       服饰  19930603
# 19  000027.SZ  000027   深圳能源   深圳     火力发电  19930903

# %% [markdown]
# ### 输入

# %%
#  ts_code      TS股票代码
#  name         名称
#  market       市场类别(主板/创业板/科创板/CDR/北交所)
#  list_status  上市状态 L上市 D退市 P暂停上市 G过会未交易，默认是L
#  exchange	    交易所 SSE上交所 SZSE深交所 BSE北交所
#  is_hs	    是否沪深港通标的，N否 H沪股通 S深股通

# %% [markdown]
# ### 输出

# %%
#   ts_code  TS代码
#   symbol   股票代码
#   name     股票名称
#   industry 所属行业
#   market   市场类型（主板/创业板/科创板/CDR）
#   exchange 交易所代码
#list_status 上市状态 L上市 D退市 G过会未交易 P暂停上市
#  list_date 上市日期
#delist_date 退市日期
#   is_hs    是否沪深港通标的，N否 H沪股通 S深股通

# %% [markdown]
# # End
