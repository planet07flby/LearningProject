# %% [markdown]
# # stock_company

# %%
# 描述：获取上市公司基本信息

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stock_company(exchange='SSE', fields='ts_code,chairman,manager,secretary,reg_capital,setup_date,province,main_business')
df.head(20)
# Out:
#       ts_code     chairman        manager secretary  reg_capital setup_date  \
# 0   688322.SH          黄源浩            黄源浩        靳尚   40114.4240   20130118
# 1   603838.SH          邓建华            蔡镇通        张平   32001.6000   19970829
# 2   603856.SH          倪奉尧            倪奉尧       寻金龙   28205.6060   20080121
# 3   688026.SH          袁建华  Yuan Ye James       袁建华   14036.4345   20010411
# 4   688805.SH          许建益            姚海锋        许卉   12576.0000   20131211
# 5   603395.SH           陈勇            陈国庆        邹斌   26000.0000   20120326
# 6   603288.SH          管江华            管江华        柯莹  585182.4944   20000408
# 7   688248.SH          姜海龙            姜海龙       赵子艺   56470.0000   19880222
# 8   603277.SH          周俊杰            朱文伟       鲁灵鹏   61369.9305   20030410
# 9   603258.SH          胡建平            胡建平       张济亮   24389.6700   20080901
# 10  688259.SH  YAOLONG TAN    YAOLONG TAN       占一宇   11170.0000   20060802
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code  exchange

# %% [markdown]
# ### 输出

# %%
# ts_code 股票代码
# com_name 公司全称
# exchange 交易所代码
# chairman 董事长
# manager 总经理
# secretary 董秘
# reg_capital 注册资本(万元)
# setup_date 成立日期
# province 省份
# main_business 主要业务及产品

# %% [markdown]
# # End
