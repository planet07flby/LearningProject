# %% [markdown]
# # stk_rewards

# %%
# 描述：获取上市公司高管持股和股票期权激励信息

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.stk_rewards(ts_code='000001.SZ,600001.SH')
df.head(20)
# Out:
#       ts_code  ann_date  end_date name         title     reward  hold_vol
# 0   000001.SZ  20250315  20241231  谢永林           董事长        NaN   26700.0
# 1   000001.SZ  20250315  20241231  冀光恒         董事,行长  4158700.0       0.0
# 2   000001.SZ  20250315  20241231  郭晓涛            董事        NaN       0.0
# 3   000001.SZ  20250315  20241231  蔡方方            董事        NaN       0.0
# 4   000001.SZ  20250315  20241231   付欣            董事        NaN       0.0
# 5   000001.SZ  20250315  20241231   郭建            董事   350600.0       0.0
# 6   000001.SZ  20250315  20241231  项有志  董事,副行长,首席财务官  2815500.0   26000.0
# 7   000001.SZ  20250315  20241231  杨志群        董事,副行长  2684100.0   50000.0
# 8   000001.SZ  20250315  20241231   杨军          独立董事   482600.0       0.0
# 9   000001.SZ  20250315  20241231  艾春荣          独立董事   514200.0       0.0
# 10  000001.SZ  20250315  20241231  吴志攀          独立董事   489000.0       0.0
# 11  000001.SZ  20250315  20241231   刘峰          独立董事   515600.0       0.0
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code 股票代码，支持单个或多个股票输入

# %% [markdown]
# ### 输出

# %%
# ts_code 股票代码
# ann_date 公告日期
# end_date 结束日期
# name 姓名
# title 职务
# reward 报酬
# hold_vol 持股数量

# %% [markdown]
# # End
