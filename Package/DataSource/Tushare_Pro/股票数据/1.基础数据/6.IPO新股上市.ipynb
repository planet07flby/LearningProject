# %% [markdown]
# # new_share

# %%
# 描述：获取IPO新股上市信息

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.new_share(start_date='20200101', end_date='20200601')
df.head(20)
# Out:
#       ts_code sub_code   name  ipo_date issue_date   amount  market_amount  \
# 0   002989.SZ   002989   中天精装  20200601   20200610   3785.0         3407.0
# 1   688599.SH   787599   天合光能  20200529   20200610  31020.0         8903.0
# 2   688157.SH   787157   松井股份  20200527   20200609   1990.0          756.0
# 3   688312.SH   787312   燕麦科技  20200527   20200608   3587.0         1241.0
# 4   300838.SZ   300838   浙江力诺  20200527   20200608   3409.0         3068.0
# 5   300837.SZ   300837   浙矿股份  20200526   20200605   2500.0         2250.0
# 6   601827.SH   780827   三峰环境  20200521   20200605  37827.0        34044.0
# 7   688360.SH   787360   德马科技  20200521   20200602   2142.0          814.0
# 8   002986.SZ   002986   宇新股份  20200521   20200602   2834.0         2551.0
# 9   605288.SH   707288   凯迪股份  20200520   20200601   1250.0         1250.0
# 10  600918.SH   730918   中泰证券  20200520   20200603  69686.0        62718.0
# ...

# %% [markdown]
# ### 输入

# %%
# start_date 上网发行开始日期
# end_date 上网发行结束日期

# %% [markdown]
# ### 输出

# %%
# ts_code 股票代码
# sub_code 申购代码
# name 股票名称
# ipo_date 上网发行日期
# issue_date 上市日期
# amount 发行数量(万股)
# market_amount 上网发行数量(万股)
# price 发行价格(元)
# pe 发行市盈率
# limit_amount 个人申购上限(万股)
# funds 募集资金(亿元)
# ballot 中签率

# %% [markdown]
# # End
