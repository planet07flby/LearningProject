# %% [markdown]
# # moneyflow_hsgt

# %%
# 描述:获取沪股通、深股通、港股通每日资金流向数据

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.moneyflow_hsgt(trade_date='20260227')
df
# Out:
#   trade_date    ggt_ss    ggt_sz        hgt        sgt north_money south_money
# 0   20260227  29047.03  23574.77  161691.04  179851.79   341542.83     52621.8

# %% [markdown]
# ### 输入

# %%
# trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# trade_date
# ggt_sh 港股通(上海) ggt_sz 港股通(深圳) hgt 沪股通(百万元) sgt 深股通(百万元)
# north_money(百万元) south_money(百万元)

# %% [markdown]
# # End
