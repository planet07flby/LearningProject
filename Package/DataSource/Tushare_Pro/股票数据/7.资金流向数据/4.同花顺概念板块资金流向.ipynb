# %% [markdown]
# # moneyflow_cnt_ths

# %%
# 描述:获取同花顺概念板块每日资金流向

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.moneyflow_cnt_ths(trade_date='20250320')
df
# Out:
#     trade_date    ts_code     name lead_stock  close_price  pct_change  \
# 0     20250320  885748.TI      可燃冰       海默科技         7.99        4.76
# 1     20250320  886008.TI      减速器       大叶股份        21.22        2.60
# 2     20250320  885426.TI     海工装备       天海防务         6.97        2.56
# 3     20250320  885372.TI      页岩气       海默科技         7.99        2.21
# 4     20250320  886000.TI    一体化压铸       今飞凯达         5.57        1.78
# ..         ...        ...      ...        ...          ...         ...
# 389   20250320  885881.TI      云办公      *ST鹏博         1.72       -1.36
# 390   20250320  885947.TI  DRG/DIP       国新健康        12.82       -1.38
# 391   20250320  885975.TI    电子身份证        拓尔思        24.16       -1.40
# 392   20250320  885874.TI      云游戏      *ST鹏博         1.72       -1.75
# 393   20250320  886091.TI     华为手机       凯格精机        37.23       -2.25
#
#      industry_index  company_num  pct_change_stock  net_buy_amount  \
# 0           1307.56           12              4.76            21.0
# 1           1862.58          103              2.60           227.0
# 2           2711.31           85              2.56           171.0
# 3           2103.88           40              2.21            53.0
# 4           1213.60           50              1.78            95.0
# ..              ...          ...               ...             ...
# 389         1862.72           45             -1.36            54.0
# 390         1092.62           23             -1.38            25.0
# 391         1438.42           40             -1.40            28.0
# 392         1330.68           27             -1.75            67.0
# 393         1183.33           35             -2.25            49.0
#
#      net_sell_amount  net_amount
# 0               19.0         1.0
# 1              235.0        -8.0
# 2              148.0        23.0
# 3               42.0        10.0
# 4               86.0         9.0
# ..               ...         ...
# 389             63.0        -9.0
# 390             30.0        -5.0
# 391             39.0       -11.0
# 392             91.0       -23.0
# 393             68.0       -18.0
#
# [394 rows x 12 columns]

# %% [markdown]
# ### 输入

# %%
# ts_code trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# trade_date ts_code name
# lead_stock 领涨股票名称
# close_price 最新价
# pct_change 行业涨跌幅
# industry_index 板块指数
# company_num 公司数量
# pct_change_stock 领涨股涨跌幅
# net_buy_amount 流入资金(亿元)
# net_sell_amount 流出资金(亿元)
# net_amount 净额(亿元)

# %% [markdown]
# # End
