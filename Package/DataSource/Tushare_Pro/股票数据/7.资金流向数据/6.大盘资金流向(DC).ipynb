# %% [markdown]
# # moneyflow_mkt_dc

# %%
# 描述：获取东方财富大盘资金流向数据 6000

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.moneyflow_mkt_dc(trade_date='20260227')
df
# Out:
#   trade_date  close_sh  pct_change_sh  close_sz  pct_change_sz    net_amount  \
# 0   20260227   4162.88           0.39  14495.09          -0.06 -2.785236e+10
#
#    net_amount_rate  buy_elg_amount  buy_elg_amount_rate  buy_lg_amount  \
# 0            -1.12   -7.731294e+09                -0.31  -2.012107e+10
#
#    buy_lg_amount_rate  buy_md_amount  buy_md_amount_rate  buy_sm_amount  \
# 0               -0.81   1.183334e+09                0.05   2.666903e+10
#
#    buy_sm_amount_rate
# 0                1.07

# %% [markdown]
# ### 输入

# %%
# trade_date start_date end_date

# %% [markdown]
# ### 输出

# %%
# trade_date
# close_sh 上证收盘价(点,下同)
# pct_change_sh 上证涨跌幅(%,下同)
# close_sz pct_change_sz
# net_amount(元) net_amount_rate(%) buy_elg_amount buy_elg_amount_rate buy_lg_amount
# buy_lg_amount_rate buy_md_amount buy_md_amount_rate buy_sm_amount buy_sm_amount_rate

# %% [markdown]
# # End
