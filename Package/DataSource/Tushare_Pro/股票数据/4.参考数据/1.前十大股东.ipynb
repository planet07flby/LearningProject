# %% [markdown]
# # top10_holders

# %%
# 描述:获取上市公司前十大股东数据,包括持有数量和比例等信息

# %%
import tushare as ts
pro = ts.pro_api()
df = pro.top10_holders(ts_code='601899.SH',ann_date='20251018')
df.hold_amount = df.hold_amount.astype(int)
df.sort_values('hold_amount', ascending=False, inplace=True)
df
# Out:
#      ts_code  ann_date  end_date                             holder_name  \
# 2  601899.SH  20251018  20250930                        闽西兴杭国有资产投资经营有限公司
# 1  601899.SH  20251018  20250930                         香港中央结算(代理人)有限公司
# 0  601899.SH  20251018  20250930                              香港中央结算有限公司
# 4  601899.SH  20251018  20250930                            中国证券金融股份有限公司
# 7  601899.SH  20251018  20250930               中国工商银行-上证50交易型开放式指数证券投资基金
# 6  601899.SH  20251018  20250930    中国工商银行股份有限公司-华泰柏瑞沪深300交易型开放式指数证券投资基金
# 8  601899.SH  20251018  20250930      中国人寿保险股份有限公司-传统-普通保险产品-005L-CT001沪
# 5  601899.SH  20251018  20250930  中国建设银行股份有限公司-易方达沪深300交易型开放式指数发起式证券投资基金
# 9  601899.SH  20251018  20250930           上海高毅资产管理合伙企业(有限合伙)-高毅晓峰2号致信基金
# 3  601899.SH  20251018  20250930                                国新投资有限公司
#
#    hold_amount  hold_ratio  hold_float_ratio  hold_change holder_type
# 2   6083517704     22.8897           29.5489          0.0         国资局
# ...

# %% [markdown]
# ### 输入

# %%
# ts_code period ann_date 公告日期 start_date end_date

# %% [markdown]
# ### 输出

# %%
# ts_code ann_date
# holder_name 股东名称 hold_amount 持有数量(股) hold_ratio 占总股本比例(%) hold_float_ratio 占流通股本比例(%) hold_change 持股变动 holder_type 股东类型

# %% [markdown]
# # End
