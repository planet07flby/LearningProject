# %% [markdown]
# ## 调取数据

# %%
import tushare as ts
ts.set_token('b7bf12884a6ba2a5b33717fea342a6e8d3ab2fa80b5bb8ff6682e20f')
# set_token只需要在第一次或者token失效后调用 正常情况下忽略此步

# %% [markdown]
# #### 初始化pro接口

# %%
pro = ts.pro_api()

# %% [markdown]
# #### 数据调取

# %%
df = pro.trade_cal(exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# %%
df
# Out:
#    exchange  cal_date  is_open pretrade_date
# 0       SSE  20181001        0      20180928
# 1       SSE  20180930        0      20180928
# 2       SSE  20180929        0      20180928
# 3       SSE  20180924        0      20180921
# 4       SSE  20180923        0      20180921
# 5       SSE  20180922        0      20180921
# 6       SSE  20180916        0      20180914
# 7       SSE  20180915        0      20180914
# 8       SSE  20180909        0      20180907
# 9       SSE  20180908        0      20180907
# 10      SSE  20180902        0      20180831
# 11      SSE  20180901        0      20180831

# %% [markdown]
# ##  End
