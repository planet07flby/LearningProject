# %% [markdown]
# # 6.3 与Web API交互

# %%
import pandas as pd
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp.raise_for_status()
resp
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File D:\code\LearningProject\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File D:\code\LearningProject\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File D:\code\LearningProject\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %%
data = resp.json()
data[0]['title']

# %%
# data中每个元素都是包含Github问题页上的所有数据的字典
issues = pd.DataFrame(data,columns=['number','title','labels','state'])
issues

# %% [markdown]
# # End
